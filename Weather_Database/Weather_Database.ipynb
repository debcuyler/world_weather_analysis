# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | lebu
# Processing Record 2 of Set 1 | nelson bay
# Processing Record 3 of Set 1 | san vicente
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | montepuez
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | baruun-urt
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | mastung
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | plettenberg bay
# Processing Record 19 of Set 1 | thunder bay
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | baykit
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | kyren
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | moose factory
# Processing Record 26 of Set 1 | chuy
# Processing Record 27 of Set 1 | lidkoping
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | pisco
# Processing Record 30 of Set 1 | warri
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | brazzaville
# Processing Record 34 of Set 1 | honavar
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | nioro
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | mawlaik
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | qasigiannguit
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | lorengau
# Processing Record 46 of Set 1 | akyab
# Processing Record 47 of Set 1 | taunggyi
# Processing Record 48 of Set 1 | asau
# Processing Record 49 of Set 1 | hailar
# Processing Record 50 of Set 1 | port macquarie
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | maudaha
# Processing Record 7 of Set 2 | kaeo
# Processing Record 8 of Set 2 | gorontalo
# Processing Record 9 of Set 2 | chapais
# Processing Record 10 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | lumby
# Processing Record 14 of Set 2 | nanortalik
# Processing Record 15 of Set 2 | constitucion
# Processing Record 16 of Set 2 | hokitika
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | bathsheba
# Processing Record 19 of Set 2 | vaitape
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 2 | kholodnyy
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | soavinandriana
# Processing Record 25 of Set 2 | north bend
# Processing Record 26 of Set 2 | port-gentil
# Processing Record 27 of Set 2 | olinda
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | saint-denis
# Processing Record 30 of Set 2 | victoria
# Processing Record 31 of Set 2 | maniitsoq
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | lavrentiya
# Processing Record 35 of Set 2 | coihaique
# Processing Record 36 of Set 2 | husavik
# Processing Record 37 of Set 2 | general pico
# Processing Record 38 of Set 2 | rehoboth
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | tiksi
# Processing Record 43 of Set 2 | havelock
# Processing Record 44 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 2 | shambu
# Processing Record 47 of Set 2 | sola
# Processing Record 48 of Set 2 | muncar
# Processing Record 49 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 2 | prado
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | grootfontein
# Processing Record 5 of Set 3 | mahebourg
# Processing Record 6 of Set 3 | mar del plata
# Processing Record 7 of Set 3 | atuona
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 3 | agadir
# Processing Record 11 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 3 | maturin
# Processing Record 13 of Set 3 | tahta
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | tromso
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | bluff
# Processing Record 18 of Set 3 | barcelos
# Processing Record 19 of Set 3 | port blair
# Processing Record 20 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | seoul
# Processing Record 23 of Set 3 | hermanus
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | oskarshamn
# Processing Record 27 of Set 3 | cidreira
# Processing Record 28 of Set 3 | huancavelica
# Processing Record 29 of Set 3 | atherton
# Processing Record 30 of Set 3 | griffith
# Processing Record 31 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 3 | haines junction
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | inirida
# Processing Record 35 of Set 3 | bundaberg
# Processing Record 36 of Set 3 | dikson
# Processing Record 37 of Set 3 | touros
# Processing Record 38 of Set 3 | ayios andreas
# City not found. Skipping...
# Processing Record 39 of Set 3 | paamiut
# Processing Record 40 of Set 3 | lompoc
# Processing Record 41 of Set 3 | kikwit
# Processing Record 42 of Set 3 | beihai
# Processing Record 43 of Set 3 | mackay
# Processing Record 44 of Set 3 | henties bay
# Processing Record 45 of Set 3 | rutana
# Processing Record 46 of Set 3 | sao joao da barra
# Processing Record 47 of Set 3 | klaksvik
# Processing Record 48 of Set 3 | dabat
# Processing Record 49 of Set 3 | tilichiki
# Processing Record 50 of Set 3 | ayna
# Processing Record 1 of Set 4 | grindavik
# Processing Record 2 of Set 4 | dauriya
# Processing Record 3 of Set 4 | namibe
# Processing Record 4 of Set 4 | sinnamary
# Processing Record 5 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 4 | atar
# Processing Record 7 of Set 4 | sabang
# Processing Record 8 of Set 4 | lamu
# Processing Record 9 of Set 4 | svetlyy
# Processing Record 10 of Set 4 | nalut
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | chokurdakh
# Processing Record 15 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | hithadhoo
# Processing Record 19 of Set 4 | honiara
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | mana
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | marrakesh
# Processing Record 24 of Set 4 | vilhena
# Processing Record 25 of Set 4 | xiongzhou
# Processing Record 26 of Set 4 | ulladulla
# Processing Record 27 of Set 4 | tucson
# Processing Record 28 of Set 4 | bogande
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 4 | flinders
# Processing Record 32 of Set 4 | rudnogorsk
# Processing Record 33 of Set 4 | guasdualito
# Processing Record 34 of Set 4 | barrow
# Processing Record 35 of Set 4 | manicore
# Processing Record 36 of Set 4 | antalaha
# Processing Record 37 of Set 4 | piacabucu
# Processing Record 38 of Set 4 | salekhard
# Processing Record 39 of Set 4 | cherskiy
# Processing Record 40 of Set 4 | honningsvag
# Processing Record 41 of Set 4 | acarau
# Processing Record 42 of Set 4 | rokytne
# Processing Record 43 of Set 4 | golden
# Processing Record 44 of Set 4 | sisimiut
# Processing Record 45 of Set 4 | lamont
# Processing Record 46 of Set 4 | flin flon
# Processing Record 47 of Set 4 | solnechnogorsk
# Processing Record 48 of Set 4 | the valley
# Processing Record 49 of Set 4 | hobyo
# Processing Record 50 of Set 4 | katsuura
# Processing Record 1 of Set 5 | narsaq
# Processing Record 2 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 5 | bozeman
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | sibiti
# Processing Record 6 of Set 5 | vila velha
# Processing Record 7 of Set 5 | bandarbeyla
# Processing Record 8 of Set 5 | marawi
# Processing Record 9 of Set 5 | praia
# Processing Record 10 of Set 5 | montanha
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | cabo san lucas
# Processing Record 13 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 5 | mecca
# Processing Record 15 of Set 5 | roma
# Processing Record 16 of Set 5 | mazara del vallo
# Processing Record 17 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 5 | kontagora
# Processing Record 19 of Set 5 | rio grande
# Processing Record 20 of Set 5 | maldonado
# Processing Record 21 of Set 5 | kwinana
# Processing Record 22 of Set 5 | upernavik
# Processing Record 23 of Set 5 | olafsvik
# Processing Record 24 of Set 5 | gimbi
# Processing Record 25 of Set 5 | bambous virieux
# Processing Record 26 of Set 5 | tuatapere
# Processing Record 27 of Set 5 | akureyri
# Processing Record 28 of Set 5 | meulaboh
# Processing Record 29 of Set 5 | sorland
# Processing Record 30 of Set 5 | ixtapa
# Processing Record 31 of Set 5 | fukue
# Processing Record 32 of Set 5 | north bay
# Processing Record 33 of Set 5 | kavieng
# Processing Record 34 of Set 5 | rodez
# Processing Record 35 of Set 5 | nouadhibou
# Processing Record 36 of Set 5 | derby
# Processing Record 37 of Set 5 | tezu
# Processing Record 38 of Set 5 | balve
# Processing Record 39 of Set 5 | anloga
# Processing Record 40 of Set 5 | tan an
# Processing Record 41 of Set 5 | vila
# Processing Record 42 of Set 5 | leningradskiy
# Processing Record 43 of Set 5 | pilao arcado
# City not found. Skipping...
# Processing Record 44 of Set 5 | novopistsovo
# Processing Record 45 of Set 5 | churapcha
# Processing Record 46 of Set 5 | santa luzia
# Processing Record 47 of Set 5 | caravelas
# Processing Record 48 of Set 5 | medea
# Processing Record 49 of Set 5 | broome
# Processing Record 50 of Set 5 | dillon
# Processing Record 1 of Set 6 | wahlstedt
# Processing Record 2 of Set 6 | inzhavino
# Processing Record 3 of Set 6 | saiki
# Processing Record 4 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 6 of Set 6 | saint george
# Processing Record 7 of Set 6 | chicama
# Processing Record 8 of Set 6 | bengkulu
# Processing Record 9 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 6 | nushki
# Processing Record 11 of Set 6 | nanfeng
# Processing Record 12 of Set 6 | eldorado
# Processing Record 13 of Set 6 | kitimat
# Processing Record 14 of Set 6 | penzance
# Processing Record 15 of Set 6 | port lincoln
# Processing Record 16 of Set 6 | fairbanks
# Processing Record 17 of Set 6 | pervomayskoye
# Processing Record 18 of Set 6 | ouadda
# Processing Record 19 of Set 6 | creel
# Processing Record 20 of Set 6 | samarai
# Processing Record 21 of Set 6 | athabasca
# Processing Record 22 of Set 6 | badiraguato
# Processing Record 23 of Set 6 | sibolga
# Processing Record 24 of Set 6 | deputatskiy
# Processing Record 25 of Set 6 | road town
# Processing Record 26 of Set 6 | pak phanang
# Processing Record 27 of Set 6 | moron
# Processing Record 28 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 6 | aklavik
# Processing Record 30 of Set 6 | chapleau
# Processing Record 31 of Set 6 | yarega
# Processing Record 32 of Set 6 | kilindoni
# Processing Record 33 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 34 of Set 6 | san martin
# Processing Record 35 of Set 6 | nabire
# Processing Record 36 of Set 6 | krasnoselkup
# Processing Record 37 of Set 6 | ossora
# Processing Record 38 of Set 6 | ijuin
# Processing Record 39 of Set 6 | kavaratti
# Processing Record 40 of Set 6 | codrington
# Processing Record 41 of Set 6 | gwadar
# Processing Record 42 of Set 6 | mokhotlong
# Processing Record 43 of Set 6 | najran
# Processing Record 44 of Set 6 | vanimo
# Processing Record 45 of Set 6 | zaporizhzhya
# Processing Record 46 of Set 6 | juterbog
# Processing Record 47 of Set 6 | ketchikan
# Processing Record 48 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 49 of Set 6 | khuzhir
# Processing Record 50 of Set 6 | zhengjiatun
# Processing Record 1 of Set 7 | morgan city
# Processing Record 2 of Set 7 | luba
# Processing Record 3 of Set 7 | panguna
# Processing Record 4 of Set 7 | topolobampo
# Processing Record 5 of Set 7 | san patricio
# Processing Record 6 of Set 7 | puerto leguizamo
# Processing Record 7 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 7 | ankazobe
# Processing Record 9 of Set 7 | ginda
# Processing Record 10 of Set 7 | lumut
# Processing Record 11 of Set 7 | saint-georges
# Processing Record 12 of Set 7 | port said
# Processing Record 13 of Set 7 | amiens
# Processing Record 14 of Set 7 | kabansk
# Processing Record 15 of Set 7 | buchanan
# Processing Record 16 of Set 7 | saint-pierre
# Processing Record 17 of Set 7 | hong gai
# Processing Record 18 of Set 7 | milkovo
# Processing Record 19 of Set 7 | awjilah
# Processing Record 20 of Set 7 | fomboni
# Processing Record 21 of Set 7 | port moresby
# Processing Record 22 of Set 7 | visby
# Processing Record 23 of Set 7 | pingzhuang
# Processing Record 24 of Set 7 | general roca
# Processing Record 25 of Set 7 | yulara
# Processing Record 26 of Set 7 | nantucket
# Processing Record 27 of Set 7 | chengde
# Processing Record 28 of Set 7 | balkhash
# Processing Record 29 of Set 7 | luderitz
# Processing Record 30 of Set 7 | ponte de sor
# Processing Record 31 of Set 7 | durban
# Processing Record 32 of Set 7 | balrampur
# Processing Record 33 of Set 7 | dunedin
# Processing Record 34 of Set 7 | khuzdar
# Processing Record 35 of Set 7 | zarichne
# Processing Record 36 of Set 7 | iberia
# Processing Record 37 of Set 7 | pemangkat
# Processing Record 38 of Set 7 | jaru
# Processing Record 39 of Set 7 | kununurra
# Processing Record 40 of Set 7 | reconquista
# Processing Record 41 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 42 of Set 7 | senno
# Processing Record 43 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 7 | khandyga
# Processing Record 45 of Set 7 | doha
# Processing Record 46 of Set 7 | vanavara
# Processing Record 47 of Set 7 | tianpeng
# Processing Record 48 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 7 | redmond
# Processing Record 50 of Set 7 | san cristobal
# Processing Record 1 of Set 8 | balkanabat
# Processing Record 2 of Set 8 | ushtobe
# Processing Record 3 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 4 of Set 8 | borazjan
# Processing Record 5 of Set 8 | tasiilaq
# Processing Record 6 of Set 8 | mae hong son
# Processing Record 7 of Set 8 | rawson
# Processing Record 8 of Set 8 | gat
# Processing Record 9 of Set 8 | tambura
# Processing Record 10 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 11 of Set 8 | beloha
# Processing Record 12 of Set 8 | pedernales
# Processing Record 13 of Set 8 | guliston
# Processing Record 14 of Set 8 | nzerekore
# Processing Record 15 of Set 8 | thessalon
# Processing Record 16 of Set 8 | ambon
# Processing Record 17 of Set 8 | pacific grove
# Processing Record 18 of Set 8 | aasmae
# City not found. Skipping...
# Processing Record 19 of Set 8 | vostok
# Processing Record 20 of Set 8 | dongsheng
# Processing Record 21 of Set 8 | constantine
# Processing Record 22 of Set 8 | kalemie
# Processing Record 23 of Set 8 | south venice
# Processing Record 24 of Set 8 | sao filipe
# Processing Record 25 of Set 8 | pozarevac
# Processing Record 26 of Set 8 | pauini
# Processing Record 27 of Set 8 | heishan
# Processing Record 28 of Set 8 | leh
# Processing Record 29 of Set 8 | ayan
# Processing Record 30 of Set 8 | komsomolskiy
# Processing Record 31 of Set 8 | tessalit
# Processing Record 32 of Set 8 | ndele
# Processing Record 33 of Set 8 | praia da vitoria
# Processing Record 34 of Set 8 | waipawa
# Processing Record 35 of Set 8 | marienburg
# Processing Record 36 of Set 8 | aden
# Processing Record 37 of Set 8 | brae
# Processing Record 38 of Set 8 | darnah
# Processing Record 39 of Set 8 | shimoda
# Processing Record 40 of Set 8 | jacksonville
# Processing Record 41 of Set 8 | talnakh
# Processing Record 42 of Set 8 | antofagasta
# Processing Record 43 of Set 8 | anyang
# Processing Record 44 of Set 8 | bilibino
# Processing Record 45 of Set 8 | erenhot
# Processing Record 46 of Set 8 | namangan
# Processing Record 47 of Set 8 | inhambane
# Processing Record 48 of Set 8 | laguna
# Processing Record 49 of Set 8 | kirakira
# Processing Record 50 of Set 8 | biak
# Processing Record 1 of Set 9 | neuquen
# Processing Record 2 of Set 9 | ponta do sol
# Processing Record 3 of Set 9 | gushikawa
# Processing Record 4 of Set 9 | kudahuvadhoo
# Processing Record 5 of Set 9 | casian
# Processing Record 6 of Set 9 | kodinsk
# Processing Record 7 of Set 9 | big rapids
# Processing Record 8 of Set 9 | ancud
# Processing Record 9 of Set 9 | tautira
# Processing Record 10 of Set 9 | bereda
# Processing Record 11 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 12 of Set 9 | maningrida
# Processing Record 13 of Set 9 | kamina
# Processing Record 14 of Set 9 | lima
# Processing Record 15 of Set 9 | mount isa
# Processing Record 16 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 9 | mnogovershinnyy
# Processing Record 18 of Set 9 | mariental
# Processing Record 19 of Set 9 | port hardy
# Processing Record 20 of Set 9 | kahului
# Processing Record 21 of Set 9 | kavali
# Processing Record 22 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 23 of Set 9 | talas
# Processing Record 24 of Set 9 | nome
# Processing Record 25 of Set 9 | vysokogornyy
# Processing Record 26 of Set 9 | hofn
# Processing Record 27 of Set 9 | shostka
# Processing Record 28 of Set 9 | gamba
# Processing Record 29 of Set 9 | yaroslavskiy
# Processing Record 30 of Set 9 | daman
# Processing Record 31 of Set 9 | tura
# Processing Record 32 of Set 9 | kimbe
# Processing Record 33 of Set 9 | voh
# Processing Record 34 of Set 9 | berlevag
# Processing Record 35 of Set 9 | nogliki
# Processing Record 36 of Set 9 | causapscal
# Processing Record 37 of Set 9 | coracora
# Processing Record 38 of Set 9 | sulangan
# Processing Record 39 of Set 9 | boa vista
# Processing Record 40 of Set 9 | bud
# Processing Record 41 of Set 9 | bojnurd
# Processing Record 42 of Set 9 | hutchinson
# Processing Record 43 of Set 9 | taoudenni
# Processing Record 44 of Set 9 | anadyr
# Processing Record 45 of Set 9 | vao
# Processing Record 46 of Set 9 | vonitsa
# Processing Record 47 of Set 9 | taseyevo
# Processing Record 48 of Set 9 | bowen
# Processing Record 49 of Set 9 | saint-francois
# Processing Record 50 of Set 9 | punta de bombon
# Processing Record 1 of Set 10 | bristol
# Processing Record 2 of Set 10 | tema
# Processing Record 3 of Set 10 | mariel
# Processing Record 4 of Set 10 | mandera
# Processing Record 5 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 6 of Set 10 | korla
# Processing Record 7 of Set 10 | cheremisinovo
# Processing Record 8 of Set 10 | locri
# Processing Record 9 of Set 10 | cordele
# Processing Record 10 of Set 10 | hirara
# Processing Record 11 of Set 10 | yaan
# Processing Record 12 of Set 10 | sitka
# Processing Record 13 of Set 10 | brainerd
# Processing Record 14 of Set 10 | oranjemund
# Processing Record 15 of Set 10 | la sarre
# Processing Record 16 of Set 10 | cortez
# Processing Record 17 of Set 10 | bayonet point
# Processing Record 18 of Set 10 | capim grosso
# Processing Record 19 of Set 10 | los llanos de aridane
# Processing Record 20 of Set 10 | coxim
# Processing Record 21 of Set 10 | dolni poustevna
# Processing Record 22 of Set 10 | almaznyy
# Processing Record 23 of Set 10 | mixtequilla
# City not found. Skipping...
# Processing Record 24 of Set 10 | gerash
# Processing Record 25 of Set 10 | labuhan deli
# Processing Record 26 of Set 10 | nemuro
# Processing Record 27 of Set 10 | muktagachha
# City not found. Skipping...
# Processing Record 28 of Set 10 | rosario oeste
# Processing Record 29 of Set 10 | lazaro cardenas
# Processing Record 30 of Set 10 | almaty
# Processing Record 31 of Set 10 | ilulissat
# Processing Record 32 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 33 of Set 10 | esmeralda
# Processing Record 34 of Set 10 | tran
# Processing Record 35 of Set 10 | xingyi
# Processing Record 36 of Set 10 | dinard
# Processing Record 37 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 38 of Set 10 | kralendijk
# Processing Record 39 of Set 10 | choszczno
# Processing Record 40 of Set 10 | pangnirtung
# Processing Record 41 of Set 10 | forssa
# Processing Record 42 of Set 10 | peniche
# Processing Record 43 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 44 of Set 10 | hearst
# Processing Record 45 of Set 10 | romny
# Processing Record 46 of Set 10 | hamilton
# Processing Record 47 of Set 10 | saint-augustin
# Processing Record 48 of Set 10 | byron bay
# Processing Record 49 of Set 10 | eidfjord
# Processing Record 50 of Set 10 | portland
# Processing Record 1 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 11 | ko samui
# Processing Record 3 of Set 11 | sokoni
# Processing Record 4 of Set 11 | drumheller
# Processing Record 5 of Set 11 | buala
# Processing Record 6 of Set 11 | rogovatoye
# Processing Record 7 of Set 11 | bijawar
# Processing Record 8 of Set 11 | lagoa
# Processing Record 9 of Set 11 | omaruru
# Processing Record 10 of Set 11 | zhigansk
# Processing Record 11 of Set 11 | cayenne
# Processing Record 12 of Set 11 | beringovskiy
# Processing Record 13 of Set 11 | tirodi
# Processing Record 14 of Set 11 | presidencia roque saenz pena
# Processing Record 15 of Set 11 | clemson
# Processing Record 16 of Set 11 | yenagoa
# Processing Record 17 of Set 11 | saint-leu
# Processing Record 18 of Set 11 | alyangula
# Processing Record 19 of Set 11 | frankfort
# Processing Record 20 of Set 11 | kendari
# Processing Record 21 of Set 11 | havre-saint-pierre
# Processing Record 22 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 23 of Set 11 | kawambwa
# Processing Record 24 of Set 11 | cockburn town
# Processing Record 25 of Set 11 | along
# Processing Record 26 of Set 11 | aban
# Processing Record 27 of Set 11 | orsha
# Processing Record 28 of Set 11 | benbrook
# Processing Record 29 of Set 11 | labuhan
# Processing Record 30 of Set 11 | kloulklubed
# Processing Record 31 of Set 11 | mahanoro
# Processing Record 32 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 11 | iqaluit
# Processing Record 34 of Set 11 | rocha
# Processing Record 35 of Set 11 | ardakan
# Processing Record 36 of Set 11 | trairi
# Processing Record 37 of Set 11 | burgeo
# Processing Record 38 of Set 11 | russell
# Processing Record 39 of Set 11 | ahipara
# Processing Record 40 of Set 11 | suixi
# Processing Record 41 of Set 11 | sakakah
# Processing Record 42 of Set 11 | grand gaube
# Processing Record 43 of Set 11 | knappskog
# Processing Record 44 of Set 11 | svetlogorsk
# Processing Record 45 of Set 11 | arlit
# Processing Record 46 of Set 11 | ursulo galvan
# Processing Record 47 of Set 11 | tarakan
# Processing Record 48 of Set 11 | mapiri
# Processing Record 49 of Set 11 | forestville
# Processing Record 50 of Set 11 | shihezi
# Processing Record 1 of Set 12 | newport
# Processing Record 2 of Set 12 | muros
# Processing Record 3 of Set 12 | chinsali
# Processing Record 4 of Set 12 | dingle
# Processing Record 5 of Set 12 | mehamn
# Processing Record 6 of Set 12 | dindori
# Processing Record 7 of Set 12 | prata
# Processing Record 8 of Set 12 | arman
# Processing Record 9 of Set 12 | baisha
# Processing Record 10 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 12 | muzquiz
# City not found. Skipping...
# Processing Record 12 of Set 12 | chor
# Processing Record 13 of Set 12 | bainbridge
# Processing Record 14 of Set 12 | marsh harbour
# Processing Record 15 of Set 12 | batticaloa
# Processing Record 16 of Set 12 | etchoropo
# Processing Record 17 of Set 12 | banjar
# Processing Record 18 of Set 12 | margherita
# Processing Record 19 of Set 12 | jiehu
# Processing Record 20 of Set 12 | dzilam gonzalez
# Processing Record 21 of Set 12 | casteltermini
# Processing Record 22 of Set 12 | padang
# Processing Record 23 of Set 12 | sereflikochisar
# Processing Record 24 of Set 12 | magistralnyy
# Processing Record 25 of Set 12 | batagay-alyta
# Processing Record 26 of Set 12 | batemans bay
# Processing Record 27 of Set 12 | alta floresta
# Processing Record 28 of Set 12 | monkey bay
# Processing Record 29 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 30 of Set 12 | marsa matruh
# Processing Record 31 of Set 12 | sorong
# Processing Record 32 of Set 12 | horsham
# Processing Record 33 of Set 12 | pesochnoye
# Processing Record 34 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 12 | daru
# Processing Record 36 of Set 12 | bima
# Processing Record 37 of Set 12 | sayyan
# Processing Record 38 of Set 12 | la ronge
# Processing Record 39 of Set 12 | magole
# Processing Record 40 of Set 12 | phan thiet
# Processing Record 41 of Set 12 | nago
# Processing Record 42 of Set 12 | kholmogory
# Processing Record 43 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 44 of Set 12 | lewisporte
# Processing Record 45 of Set 12 | tecolutla
# Processing Record 46 of Set 12 | san rafael
# Processing Record 47 of Set 12 | acapulco
# Processing Record 48 of Set 12 | gravdal
# Processing Record 49 of Set 12 | adrar
# Processing Record 50 of Set 12 | isangel
# Processing Record 1 of Set 13 | fort frances
# Processing Record 2 of Set 13 | ryotsu
# Processing Record 3 of Set 13 | caucaia
# Processing Record 4 of Set 13 | denpasar
# Processing Record 5 of Set 13 | mogadishu
# Processing Record 6 of Set 13 | saldanha
# Processing Record 7 of Set 13 | lastoursville
# Processing Record 8 of Set 13 | vestmannaeyjar
# Processing Record 9 of Set 13 | laukaa
# Processing Record 10 of Set 13 | olovyannaya
# Processing Record 11 of Set 13 | soe
# Processing Record 12 of Set 13 | ostrovnoy
# Processing Record 13 of Set 13 | voyvozh
# Processing Record 14 of Set 13 | kant
# Processing Record 15 of Set 13 | medveditskiy
# Processing Record 16 of Set 13 | lhokseumawe
# Processing Record 17 of Set 13 | tahoua
# Processing Record 18 of Set 13 | coronado
# Processing Record 19 of Set 13 | kirensk
# Processing Record 20 of Set 13 | boromo
# Processing Record 21 of Set 13 | ulcinj
# Processing Record 22 of Set 13 | srednekolymsk
# Processing Record 23 of Set 13 | los gatos
# Processing Record 24 of Set 13 | yar-sale
# Processing Record 25 of Set 13 | agboville
# Processing Record 26 of Set 13 | sompeta
# Processing Record 27 of Set 13 | traverse city
# Processing Record 28 of Set 13 | sao lourenco
# Processing Record 29 of Set 13 | aranos
# Processing Record 30 of Set 13 | stuttgart
# Processing Record 31 of Set 13 | albanel
# Processing Record 32 of Set 13 | pilar
# Processing Record 33 of Set 13 | staryy nadym
# Processing Record 34 of Set 13 | tornio
# Processing Record 35 of Set 13 | mirandola
# Processing Record 36 of Set 13 | grants
# Processing Record 37 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 38 of Set 13 | dinguiraye
# Processing Record 39 of Set 13 | saint anthony
# Processing Record 40 of Set 13 | qui nhon
# Processing Record 41 of Set 13 | ondjiva
# Processing Record 42 of Set 13 | balotra
# Processing Record 43 of Set 13 | cedar city
# Processing Record 44 of Set 13 | hay river
# Processing Record 45 of Set 13 | shchelkun
# Processing Record 46 of Set 13 | erdenet
# Processing Record 47 of Set 13 | bambanglipuro
# Processing Record 48 of Set 13 | klyuchi
# Processing Record 49 of Set 13 | garden city
# Processing Record 50 of Set 13 | nizwa
# Processing Record 1 of Set 14 | nanuque
# Processing Record 2 of Set 14 | esso
# Processing Record 3 of Set 14 | huitzuco
# City not found. Skipping...
# Processing Record 4 of Set 14 | yanam
# Processing Record 5 of Set 14 | luau
# Processing Record 6 of Set 14 | altay
# Processing Record 7 of Set 14 | cheney
# Processing Record 8 of Set 14 | lachi
# Processing Record 9 of Set 14 | faya
# Processing Record 10 of Set 14 | tabulbah
# City not found. Skipping...
# Processing Record 11 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 14 | porto nacional
# Processing Record 13 of Set 14 | qaqortoq
# Processing Record 14 of Set 14 | pozo colorado
# Processing Record 15 of Set 14 | belaya gora
# Processing Record 16 of Set 14 | lakhimpur
# Processing Record 17 of Set 14 | miyako
# Processing Record 18 of Set 14 | aswan
# Processing Record 19 of Set 14 | bubaque
# Processing Record 20 of Set 14 | carutapera
# Processing Record 21 of Set 14 | springbok
# Processing Record 22 of Set 14 | abilene
# Processing Record 23 of Set 14 | puerto berrio
# Processing Record 24 of Set 14 | shiyan
# Processing Record 25 of Set 14 | quelimane
# Processing Record 26 of Set 14 | abha
# Processing Record 27 of Set 14 | mathbaria
# Processing Record 28 of Set 14 | alofi
# Processing Record 29 of Set 14 | merauke
# Processing Record 30 of Set 14 | terney
# Processing Record 31 of Set 14 | larsnes
# Processing Record 32 of Set 14 | patti
# Processing Record 33 of Set 14 | salinopolis
# Processing Record 34 of Set 14 | vallenar
# Processing Record 35 of Set 14 | aosta
# Processing Record 36 of Set 14 | ajdabiya
# Processing Record 37 of Set 14 | seminole
# Processing Record 38 of Set 14 | makakilo city
# Processing Record 39 of Set 14 | kualakapuas
# Processing Record 40 of Set 14 | changde
# Processing Record 41 of Set 14 | thinadhoo
# Processing Record 42 of Set 14 | japura
# Processing Record 43 of Set 14 | akhnur
# Processing Record 44 of Set 14 | glubokoe
# City not found. Skipping...
# Processing Record 45 of Set 14 | comodoro rivadavia
# Processing Record 46 of Set 14 | hvolsvollur
# Processing Record 47 of Set 14 | gamboula
# Processing Record 48 of Set 14 | fortuna
# Processing Record 49 of Set 14 | gold coast
# Processing Record 50 of Set 14 | kotaparh
# Processing Record 1 of Set 15 | pirenopolis
# Processing Record 2 of Set 15 | chardara
# Processing Record 3 of Set 15 | vandra
# Processing Record 4 of Set 15 | tanete
# Processing Record 5 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 6 of Set 15 | jining
# Processing Record 7 of Set 15 | kizilskoye
# Processing Record 8 of Set 15 | achisay
# City not found. Skipping...
# Processing Record 9 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 15 | nybro
# Processing Record 11 of Set 15 | kuching
# Processing Record 12 of Set 15 | luganville
# Processing Record 13 of Set 15 | kropotkin
# Processing Record 14 of Set 15 | taian
# Processing Record 15 of Set 15 | viedma
# Processing Record 16 of Set 15 | sangar
# Processing Record 17 of Set 15 | dilla
# Processing Record 18 of Set 15 | camargo
# Processing Record 19 of Set 15 | tocopilla
# Processing Record 20 of Set 15 | waddan
# Processing Record 21 of Set 15 | phalaborwa
# Processing Record 22 of Set 15 | brive-la-gaillarde
# Processing Record 23 of Set 15 | mitu
# Processing Record 24 of Set 15 | gizo
# Processing Record 25 of Set 15 | texistepeque
# Processing Record 26 of Set 15 | vale
# Processing Record 27 of Set 15 | nyrob
# Processing Record 28 of Set 15 | machali
# Processing Record 29 of Set 15 | koutsouras
# Processing Record 30 of Set 15 | werda
# Processing Record 31 of Set 15 | durres
# Processing Record 32 of Set 15 | lianzhou
# Processing Record 33 of Set 15 | alice springs
# Processing Record 34 of Set 15 | edd
# Processing Record 35 of Set 15 | broken hill
# Processing Record 36 of Set 15 | baikunthpur
# Processing Record 37 of Set 15 | judayta
# Processing Record 38 of Set 15 | hambantota
# Processing Record 39 of Set 15 | sumbawanga
# Processing Record 40 of Set 15 | eskisehir
# Processing Record 41 of Set 15 | usukhchay
# Processing Record 42 of Set 15 | umm ruwabah
# City not found. Skipping...
# Processing Record 43 of Set 15 | santa vitoria do palmar
# Processing Record 44 of Set 15 | margate
# Processing Record 45 of Set 15 | yeppoon
# Processing Record 46 of Set 15 | porcia
# Processing Record 47 of Set 15 | la union
# Processing Record 48 of Set 15 | placido de castro
# Processing Record 49 of Set 15 | harper
# Processing Record 50 of Set 15 | safakulevo
# Processing Record 1 of Set 16 | mentok
# City not found. Skipping...
# Processing Record 2 of Set 16 | mandalgovi
# Processing Record 3 of Set 16 | sumbe
# Processing Record 4 of Set 16 | puerto del rosario
# Processing Record 5 of Set 16 | bijie
# Processing Record 6 of Set 16 | kragujevac
# Processing Record 7 of Set 16 | aksarka
# Processing Record 8 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 9 of Set 16 | formoso do araguaia
# City not found. Skipping...
# Processing Record 10 of Set 16 | mikhaylov
# Processing Record 11 of Set 16 | kismayo
# Processing Record 12 of Set 16 | aarup
# City not found. Skipping...
# Processing Record 13 of Set 16 | nakhon phanom
# Processing Record 14 of Set 16 | crixas
# Processing Record 15 of Set 16 | brownsville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Lebu      CL -37.6167  -73.6500     59.02        76          56
# 1    Nelson Bay      AU -32.7167  152.1500     60.01        77          11
# 2   San Vicente      AR -26.6167  -54.1333     76.10        59         100
# 3         Vaini      TO -21.2000 -175.2000     75.20        88          20
# 4  Kruisfontein      ZA -34.0033   24.7314     64.99        84         100
# 5       Rikitea      PF -23.1203 -134.9692     77.94        74          74
# 6     Montepuez      MZ -13.1256   38.9997     66.20        97          16
# 7        Albany      US  42.6001  -73.9662     52.00        78         100
# 8       Ushuaia      AR -54.8000  -68.3000     53.60        32          20
# 9        Hasaki      JP  35.7333  140.8333     41.00        93          20
#
#    Wind Speed Current Description
# 0       11.99       broken clouds
# 1        6.91          few clouds
# 2        1.05       moderate rain
# 3        5.75          few clouds
# 4        1.99     overcast clouds
# 5        7.94          light rain
# 6        3.47          few clouds
# 7        7.43       moderate rain
# 8        5.75          few clouds
# 9        5.75          few clouds

# %%
# Create the output file (csv)
output_data_file = "WeatherPy_Database.csv"
#Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label = "City_ID")
